# %% [markdown]
# # StudyCrate Sample Notebook
#
# Sneak peek of our premium content.

# %%
import math
nums = [1, 2, 3, 4, 5]
summary = {"count": len(nums), "mean": sum(nums) / len(nums), "variance": sum((x - sum(nums) / len(nums))**2 for x in nums) / len(nums)}
summary

# %% [markdown]
# ---
#
# Get the full notebooks + datasets inside StudyCrate kits.
